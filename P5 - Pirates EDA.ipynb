# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gp

# %%
df = pd.read_csv('./datasets/cleaned_pirate_activity.csv', index_col = 0)

# %%
df.head()
# Out:
#    index           X          Y  subreg                           hostility_d  \
# 0      0  -75.133333  21.933333      26                         cuban gunboat
# 1      1  108.000000   3.000000      71                               pirates
# 2      2   90.000000  -1.000000      61                               pirates
# 3      3   42.000000  14.000000      62  peoples democratic republic of yemen
# 4      4   80.300000  13.100000      63                               pirates
#
#                  victim_d                                        description  \
# 0          belesbat queen  a cuban gunboat commandeered luxury yacht bele...
# 1        ro/ro sea dragon  20 march 1990. borneo.                        ...
# 2           ro/ro sunrise  20 march 1990. singapore.                     ...
# 3           u.s. mariners  red sea, yemen                                ...
# 4  lash stonewall jackson  indian ocean                                  ...
#
# ...

# %%
#the shape files are currently to large to upload to github enterprise so they have been removed for now.



#world = gp.read_file("./gadm36_shp/gadm36.shx")

# https://geopandas.org/docs/user_guide/data_structures.html
# https://towardsdatascience.com/the-easiest-way-to-plot-data-from-pandas-on-a-world-map-1a62962a27f3
# https://gadm.org/download_world.html

#fig, ax = plt.subplots(figsize = (10, 20))
#world.plot(ax = ax)
#df.plot(x='X', y = 'Y', kind = 'scatter', color = 'red', ax = ax);

# %%
#Nav area

# %%
#subregions

# %%
#hostilities

# %%
#victims
